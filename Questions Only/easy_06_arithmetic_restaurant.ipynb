# %% [markdown]
# Quiz 06 — Arithmetic Operations
# Theme  : Restaurant Bills
# Topics : element-wise +, -, *, /, np.round
#
# SCENARIO
# 8 restaurant tables have food bills (£) and drink bills (£):
# food   = [45.5, 30.0, 62.0, 18.5, 55.0, 40.0, 72.5, 25.0]
# drinks = [12.0, 8.5,  20.0,  5.0, 15.5, 10.0, 22.0,  7.5]
#
# TASKS
# 1. Create both arrays.
# 2. Calculate the total bill per table (food + drinks).
# 3. Apply a 10% service charge to total bills. Round to 2 dp.
# 4. Give table 5 a £5 discount — update only that element.
# 5. Print the final bills after discount.
#
# EXPECTED OUTPUT
# Total bills    : [57.5  38.5  82.  23.5  70.5  50.  94.5  32.5]
# After service  : [63.25 42.35 90.2  25.85 77.55 55.  103.95  35.75]
# After discount : [63.25 42.35 90.2  25.85 72.55 55.  103.95  35.75]

# %%
import numpy as np

food   = [45.5, 30.0, 62.0, 18.5, 55.0, 40.0, 72.5, 25.0]
drinks = [12.0,  8.5, 20.0,  5.0, 15.5, 10.0, 22.0,  7.5]

# ── write your solution below ──────────────────────────────────────────────

food_arr = np.array(food)
drink_arr = np.array(drinks)

total_bill = food_arr + drink_arr

print(total_bill)
calculate = (total_bill * 100) / 10
service_fee = ((total_bill + calculate) / 10)

print(service_fee)

discount = (service_fee[3] - 5).view()

print(service_fee(discount))
# Out:
# [57.5 38.5 82.  23.5 70.5 50.  94.5 32.5]
# [ 63.25  42.35  90.2   25.85  77.55  55.   103.95  35.75]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 21
#      17 print(service_fee)
#      19 discount = (service_fee[3] - 5).view()
# ---> 21 print(service_fee(discount))
#
# TypeError: 'numpy.ndarray' object is not callable
