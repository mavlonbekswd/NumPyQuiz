# %% [markdown]
# Quiz 21 — Boolean Masking + Filtering + Aggregation
# Theme  : Grocery Sales
# Topics : boolean masks, compound conditions, masked stats, np.where
# Difficulty: Medium
#
# SCENARIO
# A supermarket tracks daily sales (£) across 5 departments over 4 weeks (28 days).
# Use seed=7 to generate: sales = np.random.randint(200, 1200, size=(4, 7))
# Rows = weeks, Columns = days (Mon–Sun)
#
# TASKS
# 1. Generate the sales array with seed=7.
# 2. Find all daily sales above the overall mean — print the count and their values.
# 3. Find days (across all weeks) where sales were between £500 and £800 inclusive.
# 4. For each week, calculate the mean. Then use np.where to label weeks
#    as "Strong" (mean >= 700) or "Weak" (mean < 700).
# 5. Print the highest-selling day of each week (max per row) and its day index.
#
# EXPECTED OUTPUT (seed=7):
# Mean sales: 693.57
# Above-mean count: 14
# Sales 500-800: [...]
# Week means    : [...]
# Week labels   : ['Strong'/'Weak' ...]
# Peak day per week indices: [...]

# %%
import numpy as np

np.random.seed(7)
sales = np.random.randint(200, 1200, size=(4, 7))

# ── write your solution below ──────────────────────────────────────────────
