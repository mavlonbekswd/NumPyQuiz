# %% [markdown]
# Quiz 48 — Football Player Performance + Ranking
# Theme  : Football Player Stats
# Topics : argsort, fancy indexing, percentile, np.lexsort, visualisation
# Difficulty: Hard  |  Business Case
#
# SCENARIO
# 20 players, 5 performance metrics: [Goals, Assists, PassAcc%, Tackles, Rating]
# Generate with seed=110:
#   goals    = np.random.randint(0, 30, 20)
#   assists  = np.random.randint(0, 20, 20)
#   pass_acc = np.random.uniform(60, 95, 20)
#   tackles  = np.random.randint(10, 80, 20)
#   rating   = np.random.uniform(5.0, 9.5, 20)
# player_names: generate "P01" to "P20"
#
# TASKS
# 1. Generate all data. Build a composite score:
#    score = goals*3 + assists*2 + (pass_acc/100)*10 + (tackles/80)*5 + rating*2
# 2. Rank all 20 players by composite score descending.
#    Print top-5 (name, score, goals, assists).
# 3. Use np.percentile to find 25th and 75th percentile of composite scores.
#    Label players as "World Class" (>=P75), "Average" (P25-P75), "Struggling" (<P25).
# 4. Among top-half players (score >= median), who has the most tackles?
# 5. Use np.lexsort to sort by rating (primary desc) then goals (secondary desc).
#    Print the top-5 from this sort.
# 6. Plot a horizontal bar chart of the top-10 players by composite score.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(110)
n            = 20
goals        = np.random.randint(0, 30, n)
assists      = np.random.randint(0, 20, n)
pass_acc     = np.random.uniform(60, 95, n)
tackles      = np.random.randint(10, 80, n)
rating       = np.random.uniform(5.0, 9.5, n)
player_names = np.array([f"P{i:02d}" for i in range(1, n+1)])

# ── write your solution below ──────────────────────────────────────────────
