# %% [markdown]
# Quiz 18 — argmax + argmin
# Theme  : Call Centre
# Topics : np.argmax, np.argmin, 2-D argmax with axis
#
# SCENARIO
# A call centre has 4 agents. We track calls handled per hour over 6 hours.
# Rows = agents, Columns = hours (9am to 2pm)
# handled = [[12,15, 8,20,18,14],
#             [10,18,12,16,22,11],
#             [14,10,16,12,20,17],
#             [ 8,14,18,14,15,20]]
#
# TASKS
# 1. Create the array.
# 2. Find which agent (row) handled the most calls overall (use sum + argmax).
# 3. Find which hour (column) was busiest overall (use sum + argmax).
# 4. For each agent, find the hour index where they were busiest (argmax axis=1).
# 5. Print all results.
#
# EXPECTED OUTPUT
# Busiest agent (index): 1
# Busiest hour  (index): 3
# Each agent's peak hour: [3 4 4 5]

# %%
import numpy as np

handled = [[12,15, 8,20,18,14],
           [10,18,12,16,22,11],
           [14,10,16,12,20,17],
           [ 8,14,18,14,15,20]]

# ── write your solution below ──────────────────────────────────────────────
