# %% [markdown]
# Quiz 20 — Fancy Indexing
# Theme  : Wedding Seating
# Topics : fancy indexing (integer array), selecting multiple rows/cols
#
# SCENARIO
# 10 wedding guests are assigned table numbers (1–5):
# guest_names  = ["Alice","Bob","Carol","Dan","Eve","Frank","Grace","Hank","Ivy","Jack"]
# table_numbers = [3, 1, 2, 5, 1, 4, 2, 3, 5, 1]
# meal_choice  = ["Veg","Fish","Meat","Veg","Meat","Fish","Veg","Meat","Fish","Veg"]
#
# TASKS
# 1. Create NumPy arrays for table_numbers and meal_choice.
# 2. Use fancy indexing to print the table numbers of guests 2, 5, and 9
#    (1-indexed → indices 1, 4, 8).
# 3. Use fancy indexing to print the meal choices for those same guests.
# 4. Find the indices of all guests at table 1 using np.where.
# 5. Print the names of guests at table 1 (use a Python list for names).
#
# EXPECTED OUTPUT
# Tables for guests 2,5,9   : [1 1 5]
# Meals for guests 2,5,9    : ['Fish' 'Meat' 'Fish']
# Table 1 guest indices     : [1 4 9]
# Table 1 guest names       : ['Bob', 'Eve', 'Jack']

# %%
import numpy as np

guest_names  = ["Alice","Bob","Carol","Dan","Eve","Frank","Grace","Hank","Ivy","Jack"]
table_numbers = np.array([3, 1, 2, 5, 1, 4, 2, 3, 5, 1])
meal_choice   = np.array(["Veg","Fish","Meat","Veg","Meat","Fish","Veg","Meat","Fish","Veg"])

# ── write your solution below ──────────────────────────────────────────────
