# %% [markdown]
# Quiz 28 — Normal Distribution
# Theme  : University Grades
# Topics : np.random.normal, histogram, mean/std verification
# Difficulty: Medium
#
# SCENARIO
# Final exam grades for 200 students follow a normal distribution:
# mean = 65, standard deviation = 12. Grades are clipped to [0, 100].
#
# TASKS
# 1. Set seed=21, generate 200 grades using np.random.normal(65, 12, 200).
# 2. Clip grades to [0, 100] using np.clip.
# 3. Print the actual mean and std of the generated data.
# 4. Count how many students scored >= 80 (distinction) and < 40 (fail).
# 5. Visualise the distribution using a Matplotlib histogram (15 bins).
#    Mark the mean with a red vertical line.
#
# EXPECTED OUTPUT
# Actual mean: ~65  |  Actual std: ~12
# Distinctions (>=80): ~25   Fails (<40): ~5

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(21)

# ── write your solution below ──────────────────────────────────────────────
