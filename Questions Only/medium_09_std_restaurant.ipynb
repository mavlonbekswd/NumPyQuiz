# %% [markdown]
# Quiz 29 — Standard Deviation + Variance
# Theme  : Restaurant Bills
# Topics : np.std, np.var, coefficient of variation, interpreting spread
# Difficulty: Medium
#
# SCENARIO
# Friday night bills (£) from 20 restaurant tables (seed=5):
# Use: bills = np.random.normal(55, 18, 20), clip to [10, 120]
#
# TASKS
# 1. Generate and clip the bills with seed=5.
# 2. Print mean, median, std, and variance.
# 3. Compute the Coefficient of Variation (CV = std/mean * 100).
# 4. Find bills within 1 standard deviation of the mean (mean ± 1*std).
#    Print count and percentage.
# 5. Identify bills more than 2 standard deviations from the mean (potential outliers).
#
# EXPECTED OUTPUT
# Mean: ~55  Median: ~54  Std: ~17  Var: ~290
# CV: ~30%
# Within 1 SD: N bills (~68%)
# Outlier candidates: [...]

# %%
import numpy as np

np.random.seed(5)

# ── write your solution below ──────────────────────────────────────────────
