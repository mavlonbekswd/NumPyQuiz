# %% [markdown]
# Quiz 57 — E-commerce Return Rate Analysis
# Theme  : E-commerce Orders
# Topics : binomial simulation, masking, group analysis, visualisation
# Difficulty: Hard  |  Business Case
#
# SCENARIO
# 5 product categories with different return rates (seed=200):
# categories  = ["Electronics","Clothing","Books","Home","Toys"]
# return_rates= [0.12, 0.25, 0.05, 0.08, 0.15]
# Monthly orders per category (6 months):
#   orders = np.random.randint(200, 1000, (5, 6))  [categories × months]
# Returns per cell: np.random.binomial(n=orders[i,j], p=return_rates[i])
#
# TASKS
# 1. Generate orders with seed=200. Generate returns cell by cell.
# 2. Compute actual return rate per category per month.
# 3. Identify month-category pairs where actual return rate > 2x the expected rate.
# 4. Revenue impact: each return costs £15 to process.
#    Compute total return cost per category over 6 months.
# 5. If return rate > 20% for any category in any month, flag for audit.
# 6. Plot actual vs expected return rate per category as a grouped bar chart.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(200)
categories   = ["Electronics","Clothing","Books","Home","Toys"]
return_rates = np.array([0.12, 0.25, 0.05, 0.08, 0.15])
orders       = np.random.randint(200, 1000, (5, 6))

# ── write your solution below ──────────────────────────────────────────────
