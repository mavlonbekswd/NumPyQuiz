# %% [markdown]
# Quiz 46 — Hotel Occupancy Analysis
# Theme  : Hotel Guests
# Topics : masking, sorting, percentile, std, argsort, visualisation
# Difficulty: Hard  |  Business Case
#
# SCENARIO
# A hotel has 5 room types across 30 nights. Seed=90.
# occupancy = np.random.randint(0, 10, (30, 5))  [nights × room_types]
# Room types: ["Standard","Superior","Deluxe","Suite","Penthouse"]
# Nightly rates: [80, 120, 180, 350, 600]
#
# TASKS
# 1. Generate data. Compute nightly revenue (occupancy × rates, broadcast).
# 2. Total revenue per room type over 30 nights.
# 3. Mean occupancy per night across all room types. Find the 5 worst nights.
# 4. Compute occupancy rate (%) = occupancy / max_capacity, where max_capacity
#    for each type = [10, 8, 6, 4, 2]. Flag nights below 30% avg as "Low nights."
# 5. For each room type: compute median occupancy, std, and the night with
#    highest occupancy (argmax).
# 6. Plot a stacked bar chart of revenue per room type per week
#    (group nights into 4 weeks of ~7 nights, pad last week if needed).

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(90)
room_types  = ["Standard","Superior","Deluxe","Suite","Penthouse"]
rates       = np.array([80, 120, 180, 350, 600])
capacity    = np.array([10, 8, 6, 4, 2])
occupancy   = np.random.randint(0, 10, (30, 5))

# ── write your solution below ──────────────────────────────────────────────
