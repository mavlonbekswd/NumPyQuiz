# %% [markdown]
# Quiz 35 — Advanced Broadcasting
# Theme  : Sales Simulation (Multi-region)
# Topics : broadcasting (3-D), shape alignment, np.newaxis
# Difficulty: Medium
#
# SCENARIO
# 3 regions × 4 products × 5 months sales matrix (units):
# Use seed=14: sales = np.random.randint(50, 500, (3, 4, 5))
# Unit prices (£) for 4 products: prices = [10, 25, 50, 80]
# Regional multipliers for 3 regions: region_mult = [1.0, 1.15, 0.90]
#
# TASKS
# 1. Generate sales with seed=14.
# 2. Reshape prices to broadcast over (3,4,5) — compute revenue per cell.
# 3. Apply region multipliers — reshape to (3,1,1) and multiply.
# 4. Print total revenue per region (sum over products and months).
# 5. Find which region-product pair generated the most revenue overall.
#
# EXPECTED OUTPUT
# Revenue shape: (3, 4, 5)
# Total per region: [£X, £Y, £Z]
# Best region-product: (region_idx, product_idx)

# %%
import numpy as np

np.random.seed(14)
sales       = np.random.randint(50, 500, (3, 4, 5))
prices      = np.array([10, 25, 50, 80])
region_mult = np.array([1.0, 1.15, 0.90])

# ── write your solution below ──────────────────────────────────────────────
