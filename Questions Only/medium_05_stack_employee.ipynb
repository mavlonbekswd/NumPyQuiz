# %% [markdown]
# Quiz 25 — Stacking + Joining + Column Operations
# Theme  : Employee Salaries
# Topics : np.column_stack, np.hstack, np.vstack, computed columns
# Difficulty: Medium
#
# SCENARIO
# HR has three separate arrays for 8 employees:
# emp_ids  = [101,102,103,104,105,106,107,108]
# salaries = [3200,4500,2800,5100,3800,4200,3600,4900]
# bonuses  = [320, 450, 280, 510, 380, 420, 360, 490]  (10% of salary)
#
# TASKS
# 1. Create the three arrays.
# 2. Compute total_pay = salary + bonus for each employee.
# 3. Stack all four arrays as columns into a (8, 4) matrix:
#    [emp_id, salary, bonus, total_pay].
# 4. Add a new batch of 3 employees by vstacking a (3,4) array onto the matrix.
#    new_data = [[109,3000,300,3300],[110,5500,550,6050],[111,2500,250,2750]]
# 5. Print the final (11, 4) table and the highest total_pay employee ID.
#
# EXPECTED OUTPUT
# Final shape: (11, 4)
# Highest paid ID: 110  Total: 6050

# %%
import numpy as np

emp_ids  = np.array([101,102,103,104,105,106,107,108])
salaries = np.array([3200,4500,2800,5100,3800,4200,3600,4900])
bonuses  = np.array([320, 450, 280, 510, 380, 420, 360, 490])

# ── write your solution below ──────────────────────────────────────────────
