# %% [markdown]
# Quiz 24 — Reshape + Axis Operations
# Theme  : Call Centre Shifts
# Topics : reshape, axis=0/1/2 (3-D), mean per shift
# Difficulty: Medium
#
# SCENARIO
# A call centre runs 2 shifts (AM/PM) per day, 5 days a week.
# 3 agents handle calls each shift. We have one week's data (60 integers):
# Use seed=3, randint(5, 30, 60) to generate raw call counts.
# Reshape into (5, 2, 3): [day, shift, agent]
#
# TASKS
# 1. Generate and reshape the data.
# 2. Print the shape and confirm it is (5, 2, 3).
# 3. Calculate the mean calls per agent across ALL days and shifts (axis=(0,1)).
# 4. Calculate total calls per day (sum over shifts and agents) — shape (5,).
# 5. Find which day had the highest total call volume.
#
# EXPECTED OUTPUT
# Shape: (5, 2, 3)
# Mean per agent (all days+shifts): [...]
# Total calls per day: [...]
# Busiest day index: N

# %%
import numpy as np

np.random.seed(3)
raw = np.random.randint(5, 30, 60)

# ── write your solution below ──────────────────────────────────────────────
