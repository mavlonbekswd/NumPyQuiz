# %% [markdown]
# Quiz 38 — Binomial Distribution
# Theme  : Call Centre
# Topics : np.random.binomial, expected value, histogram
# Difficulty: Medium
#
# SCENARIO
# A call centre agent resolves each call independently with a 70% success rate.
# The agent handles 20 calls per hour.
# Simulate 200 hours of work (seed=31).
#
# TASKS
# 1. Generate 200 hourly success counts using np.random.binomial(n=20, p=0.7, size=200).
# 2. Print the theoretical expected value (n*p) and the simulated mean.
# 3. Print the theoretical std (sqrt(n*p*(1-p))) and the simulated std.
# 4. Find the probability of resolving 15 or more calls in an hour
#    (count of hours >= 15 divided by 200).
# 5. Plot a histogram of hourly successes.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(31)

# ── write your solution below ──────────────────────────────────────────────
