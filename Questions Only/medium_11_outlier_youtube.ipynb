# %% [markdown]
# Quiz 31 — Mean vs Median + Outlier Detection
# Theme  : YouTube Analytics
# Topics : mean, median, Z-score outlier detection, visualisation
# Difficulty: Medium
#
# SCENARIO
# A YouTube channel's monthly views (thousands) for 24 months:
# views = [45,52,48,61,55,58,49,53,60,57,54,50,
#          46,59,51,56,1200,62,47,63,44,55,58,52]
# (Month 17 = viral video with 1.2M views)
#
# TASKS
# 1. Create the array.
# 2. Print mean and median — explain which is distorted.
# 3. Compute Z-scores for each month: z = (x - mean) / std
#    Flag any month with |z| > 2 as an outlier.
# 4. Remove outliers and recalculate mean and median.
# 5. Plot a line chart of views with a horizontal line at the clean mean.
#    Mark outlier months with a red dot.
#
# EXPECTED OUTPUT
# With outlier  — Mean: ~107.7k  Median: ~54.5k
# Clean mean    : ~53.4k   Clean median: ~54.0k
# Outlier months: [16]

# %%
import numpy as np
import matplotlib.pyplot as plt

views = np.array([45,52,48,61,55,58,49,53,60,57,54,50,
                  46,59,51,56,1200,62,47,63,44,55,58,52])

# ── write your solution below ──────────────────────────────────────────────
