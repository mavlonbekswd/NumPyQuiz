# %% [markdown]
# Quiz 11 — Boolean Masking
# Theme  : Gym Members
# Topics : boolean mask creation, mask application, np.count_nonzero
#
# SCENARIO
# A gym records the age of 12 members:
# ages = [17, 23, 35, 42, 19, 28, 55, 31, 16, 45, 26, 38]
#
# TASKS
# 1. Create the array.
# 2. Create a boolean mask for members aged 18 or over.
# 3. Print the mask itself.
# 4. Use the mask to filter and print only adult members' ages.
# 5. Count how many members are adults using np.count_nonzero or .sum().
#
# EXPECTED OUTPUT
# Mask   : [False  True  True  True  True  True  True  True False  True  True  True]
# Adults : [23 35 42 19 28 55 31 45 26 38]
# Count  : 10

# %%
import numpy as np

ages = [17, 23, 35, 42, 19, 28, 55, 31, 16, 45, 26, 38]

# ── write your solution below ──────────────────────────────────────────────
arr_ages = np.array(ages)
adult = arr_ages > 18
adult_age = arr_ages[arr_ages> 18]
teen = arr_ages < 18
print("Adult: ", adult)
print("Adult: ", adult_age)

print(np.count_nonzero(adult))
# Out:
# Adult:  [False  True  True  True  True  True  True  True False  True  True  True]
# Adult:  [23 35 42 19 28 55 31 45 26 38]
# 10
