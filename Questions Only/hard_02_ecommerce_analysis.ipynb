# %% [markdown]
# Quiz 42 — E-commerce Order Analysis
# Theme  : E-commerce Orders
# Topics : broadcasting, masking, argsort, percentile, stats
# Difficulty: Hard  |  Business Case
#
# SCENARIO
# 200 orders with 4 attributes: [OrderValue(£), Units, ReturnFlag(0/1), Rating(1-5)]
# Generate with seed=55:
#   values  = np.random.uniform(5, 500, 200)
#   units   = np.random.randint(1, 10, 200)
#   returns = np.random.choice([0,1], 200, p=[0.85, 0.15])   # 15% return rate
#   ratings = np.random.randint(1, 6, 200)
#
# TASKS
# 1. Stack into a (200,4) matrix. Compute revenue = value * units.
# 2. Segment orders: Low(<£50), Mid(£50-£200), High(>£200).
#    Print count and mean revenue per segment.
# 3. Compare mean rating of returned vs non-returned orders.
# 4. Find the top-10 orders by revenue (argsort); print their order index + revenue.
# 5. Apply a loyalty bonus: orders with rating 5 get 5% discount (reduce value by 5%).
#    How many orders are affected? What is the total discount given?
# 6. Print the 10th, 50th, 90th percentile of order values before and after discount.

# %%
import numpy as np

np.random.seed(55)
values  = np.random.uniform(5, 500, 200)
units   = np.random.randint(1, 10, 200)
returns = np.random.choice([0,1], 200, p=[0.85, 0.15])
ratings = np.random.randint(1, 6, 200)

# ── write your solution below ──────────────────────────────────────────────
