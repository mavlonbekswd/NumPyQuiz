# %% [markdown]
# Quiz 55 — Wedding Budget Full Analysis
# Theme  : Wedding Guests
# Topics : structured arrays, masking, broadcasting, stats, visualisation
# Difficulty: Hard  |  Business Case
#
# SCENARIO
# A wedding has 120 guests (seed=180):
#   table_no  = np.random.randint(1, 13, 120)   (12 tables, 10 seats each)
#   menu      = np.random.choice(["Meat","Fish","Veg"], 120, p=[0.5,0.3,0.2])
#   gift_amt  = np.random.normal(120, 60, 120).clip(0, 500)
#   age       = np.random.randint(5, 80, 120)
#
# Menu costs: Meat=£65, Fish=£70, Veg=£55 per person
#
# TASKS
# 1. Generate all data.
# 2. Compute total menu cost. Assign cost per guest using np.where/np.select.
# 3. Compute net cost per guest = menu_cost - gift_amt.
#    Print total net cost (positive = couple pays, negative = profit from gifts).
# 4. Table-level analysis: for each table compute total gift income,
#    total menu cost, and net. Find the "most generous" table.
# 5. Age segmentation: Children(<18), Adults(18-64), Seniors(>=65).
#    For each: count, mean gift, menu preference (most common choice).
# 6. Plot a stacked bar of menu choices (Meat/Fish/Veg) per table (12 tables).

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(180)
n        = 120
table_no = np.random.randint(1, 13, n)
menu     = np.random.choice(["Meat","Fish","Veg"], n, p=[0.5,0.3,0.2])
gift_amt = np.random.normal(120, 60, n).clip(0, 500)
age      = np.random.randint(5, 80, n)

# ── write your solution below ──────────────────────────────────────────────
