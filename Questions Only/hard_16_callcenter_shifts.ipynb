# %% [markdown]
# Quiz 56 — Call Centre Shift Optimisation
# Theme  : Call Centre
# Topics : reshape, 3-D ops, percentile, broadcasting, staffing model
# Difficulty: Hard  |  Business Case
#
# SCENARIO
# 4 weeks × 5 days × 3 shifts × 5 agents. Seed=190.
# calls = np.random.poisson(lam=12, size=(4,5,3,5))
# shift_costs (£/shift): [45, 50, 60]  (Morning, Afternoon, Evening)
# If a shift's total calls (sum over 5 agents) > 80, overtime applies:
#   overtime_cost = (total_calls - 80) * £0.50
#
# TASKS
# 1. Generate data. Compute total calls per shift-slot (sum over agents).
#    Shape becomes (4,5,3).
# 2. Compute base staffing cost per shift-slot (5 agents × shift_cost).
# 3. Identify overtime shifts (total_calls > 80). Compute overtime cost.
# 4. Compute total weekly cost (base + overtime) per week.
# 5. Find which shift type (Morning/Afternoon/Evening) has the most overtime incidents.
# 6. Suggest optimal staffing: for each shift type, print the 90th percentile
#    of calls — this is the staffing buffer needed.

# %%
import numpy as np

np.random.seed(190)
calls       = np.random.poisson(lam=12, size=(4,5,3,5))
shift_costs = np.array([45, 50, 60])
shift_names = ["Morning","Afternoon","Evening"]

# ── write your solution below ──────────────────────────────────────────────
