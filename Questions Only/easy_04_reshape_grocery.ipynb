# %% [markdown]
# Quiz 04 — Reshape
# Theme  : Grocery Sales
# Topics : np.arange, reshape, flatten
#
# SCENARIO
# A grocery chain records daily sales (£) for 12 consecutive days.
# sales = [120, 200, 150, 170, 230, 190, 140, 160, 210, 220, 180, 250]
#
# TASKS
# 1. Create the array from the list.
# 2. Reshape it into a (3, 4) array representing 3 weeks × 4 days.
# 3. Print the shape before and after reshaping.
# 4. Print only week 2 (row index 1) sales.
# 5. Flatten the reshaped array back to 1-D and confirm the shape.
#
# EXPECTED OUTPUT
# Before reshape : (12,)
# After reshape  : (3, 4)
# Week 2 sales   : [170 230 190 140]
# Flattened shape: (12,)

# %%
import numpy as np

sales = [120, 200, 150, 170, 230, 190, 140, 160, 210, 220, 180, 250]

# ── write your solution below ──────────────────────────────────────────────

arr = np.array(sales)
print(arr)
reshaped = arr.reshape(3,4)
print(reshaped)
print(reshaped.shape)
print(arr.shape)

print(reshaped[1])

flatened = reshaped.flatten()
print(flatened)
print(np.shape(flatened))
# Out:
# [120 200 150 170 230 190 140 160 210 220 180 250]
# [[120 200 150 170]
#  [230 190 140 160]
#  [210 220 180 250]]
# (3, 4)
# (12,)
# [230 190 140 160]
# [120 200 150 170 230 190 140 160 210 220 180 250]
# (12,)
