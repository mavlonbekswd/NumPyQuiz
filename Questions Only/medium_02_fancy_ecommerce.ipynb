# %% [markdown]
# Quiz 22 — Fancy Indexing + Sorting + argsort
# Theme  : E-commerce Orders
# Topics : np.argsort, fancy indexing, sorting rows by a column
# Difficulty: Medium
#
# SCENARIO
# 8 e-commerce orders with columns: [OrderID, Units, Price(£), Rating(1-5)]
# orders = [[1001, 3, 45.0, 4],
#            [1002, 1, 12.5, 5],
#            [1003, 5, 89.0, 3],
#            [1004, 2, 30.0, 4],
#            [1005, 8, 120.0, 2],
#            [1006, 1, 15.0, 5],
#            [1007, 4, 67.5, 4],
#            [1008, 6, 95.0, 3]]
#
# TASKS
# 1. Create the 2-D array.
# 2. Use argsort on column 2 (Price) to sort all orders by price ascending.
# 3. Print the top-3 most expensive orders (all columns).
# 4. Use argsort on column 3 (Rating) descending — print orders by best rating first.
# 5. Find all orders with Rating >= 4 using boolean mask; print their order IDs.
#
# EXPECTED OUTPUT
# Orders sorted by price (ascending): [rows...]
# Top 3 most expensive: [rows...]
# Orders by best rating: [rows...]
# High-rated order IDs: [1001 1002 1004 1006 1007]

# %%
import numpy as np

orders = np.array([[1001, 3, 45.0, 4],
                   [1002, 1, 12.5, 5],
                   [1003, 5, 89.0, 3],
                   [1004, 2, 30.0, 4],
                   [1005, 8,120.0, 2],
                   [1006, 1, 15.0, 5],
                   [1007, 4, 67.5, 4],
                   [1008, 6, 95.0, 3]], dtype=float)

# ── write your solution below ──────────────────────────────────────────────
