# %% [markdown]
# Quiz 52 — Stock Market Simulation
# Theme  : Stock / Sales Simulation
# Topics : random walk, cumsum, percentile, std, visualisation
# Difficulty: Hard  |  Business Case
#
# SCENARIO
# Simulate 3 stocks over 252 trading days (1 year). Seed=150.
# Daily returns follow a normal distribution:
#   Stock X: mean_return=0.0005, vol=0.015
#   Stock Y: mean_return=0.0008, vol=0.025
#   Stock Z: mean_return=0.0002, vol=0.010
# All start at £100.
#
# TASKS
# 1. Generate daily returns for each stock (shape: (252, 3)).
# 2. Compute cumulative price using np.cumprod(1 + returns, axis=0) * 100.
# 3. Print final price of each stock and total % return.
# 4. Compute 30-day rolling max drawdown for Stock Y:
#    drawdown = (price - rolling_max) / rolling_max — find the worst 30-day window.
# 5. Calculate Value at Risk (VaR) at 5% level for each stock:
#    VaR = np.percentile(returns, 5) per stock — worst expected daily loss.
# 6. Plot all 3 stock prices on one chart. Add a horizontal line at £100 (start).

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(150)
params = {"X": (0.0005, 0.015),
          "Y": (0.0008, 0.025),
          "Z": (0.0002, 0.010)}

# ── write your solution below ──────────────────────────────────────────────
