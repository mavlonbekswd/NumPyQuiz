# %% [markdown]
# Quiz 30 — Percentile + Quartiles
# Theme  : Employee Salaries
# Topics : np.percentile, IQR, boxplot visualisation
# Difficulty: Medium
#
# SCENARIO
# Annual salaries (£) for 25 employees (seed=11):
# salaries = np.random.randint(22000, 95000, 25)
#
# TASKS
# 1. Generate with seed=11.
# 2. Calculate Q1 (25th), Q2/median (50th), Q3 (75th), and 90th percentile.
# 3. Compute the Inter-Quartile Range (IQR = Q3 - Q1).
# 4. Define outlier bounds: lower = Q1 - 1.5*IQR, upper = Q3 + 1.5*IQR.
#    Print any salaries outside these bounds.
# 5. Draw a Seaborn boxplot of the salaries with a title.
#
# EXPECTED OUTPUT
# Q1: £X   Q2: £X   Q3: £X   P90: £X
# IQR: £X
# Outliers: [...] or "No outliers detected"

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(11)

# ── write your solution below ──────────────────────────────────────────────
