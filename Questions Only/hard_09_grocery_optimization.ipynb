# %% [markdown]
# Quiz 49 — Grocery Store Optimisation
# Theme  : Grocery Sales
# Topics : advanced broadcasting, masking, reshape, profit analysis
# Difficulty: Hard  |  Business Case
#
# SCENARIO
# 6 product categories, 4 stores, 8 weeks of sales volume data. Seed=120.
# sales = np.random.randint(100, 1000, (6, 4, 8))  [categories × stores × weeks]
# cost_price  (per unit): [1.5, 2.0, 3.5, 0.8, 5.0, 1.2]   (6 categories)
# sell_price  (per unit): [2.5, 3.2, 5.0, 1.5, 7.5, 2.0]   (6 categories)
#
# TASKS
# 1. Generate data. Compute profit_per_unit = sell_price - cost_price.
#    Compute total profit grid (6,4,8) via broadcasting.
# 2. Total profit per store (sum over categories and weeks).
#    Rank stores best to worst.
# 3. Total profit per category (sum over stores and weeks).
#    Which category is most profitable?
# 4. Identify underperforming store-week combinations:
#    any store-week where total sales (sum over categories) < 1500.
# 5. Apply a promotional uplift: for weeks 5-8, multiply sales volume of
#    the top-2 most profitable categories by 1.15. Recompute profit.
# 6. Print total profit before and after promotion. Calculate % improvement.

# %%
import numpy as np

np.random.seed(120)
sales       = np.random.randint(100, 1000, (6, 4, 8))
cost_price  = np.array([1.5, 2.0, 3.5, 0.8, 5.0, 1.2])
sell_price  = np.array([2.5, 3.2, 5.0, 1.5, 7.5, 2.0])

# ── write your solution below ──────────────────────────────────────────────
