# %% [markdown]
# Quiz 19 — Iteration + nditer
# Theme  : Restaurant Menu
# Topics : basic for loop over array, np.nditer, np.ndenumerate
#
# SCENARIO
# A restaurant menu has 3 courses, 4 items each (prices in £):
# menu = [[8.5,  12.0, 9.5,  11.0],   # Starters
#         [18.0, 22.5, 16.0, 24.0],   # Mains
#         [6.5,   7.0, 8.0,   9.5]]   # Desserts
#
# TASKS
# 1. Create the array.
# 2. Use a basic for loop to print each course row.
# 3. Use np.nditer to print every price with a 20% VAT amount alongside.
# 4. Use np.ndenumerate to print index + price for each item.
# 5. Print total menu revenue if every item is ordered once.
#
# (Full expected output would be long — just match the logic.)

# %%
import numpy as np

menu = [[8.5,  12.0,  9.5, 11.0],
        [18.0, 22.5, 16.0, 24.0],
        [6.5,   7.0,  8.0,  9.5]]

# ── write your solution below ──────────────────────────────────────────────
