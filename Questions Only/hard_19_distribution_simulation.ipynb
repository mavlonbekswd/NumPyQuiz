# %% [markdown]
# Quiz 59 — Combined Distribution Business Simulation
# Theme  : Call Centre + Restaurant hybrid
# Topics : binomial, poisson, normal, combined simulation, stats
# Difficulty: Hard  |  Business Case
#
# SCENARIO
# Model a restaurant's evening service over 90 days (seed=220):
#   arrivals     = Poisson(lam=25) per evening (customer groups)
#   group_size   = Binomial(n=6, p=0.55) per group (people in group)
#   spend_pp     = Normal(mean=38, std=8) per person, clipped [10, 80]
#   no_show_rate = 0.08 (8% of booked tables don't show, Binomial(n=arrivals, p=0.08))
#
# TASKS
# 1. Generate all arrays for 90 days (seed=220).
# 2. Compute actual_covers = (arrivals - no_shows) * group_size, clip to [0, inf).
# 3. Compute evening_revenue = actual_covers * spend_pp (both length 90).
# 4. Print: mean/median/std of revenue, mean covers per night.
# 5. Find the top-10 revenue evenings.
# 6. Calculate: what % of evenings exceeded £7,000 revenue?
# 7. Plot: histogram of evening revenue + overlaid normal curve fit.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats as sp_stats

np.random.seed(220)

# ── write your solution below ──────────────────────────────────────────────
