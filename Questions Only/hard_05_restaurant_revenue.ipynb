# %% [markdown]
# Quiz 45 — Restaurant Revenue Pipeline
# Theme  : Restaurant
# Topics : reshape, broadcasting, axis ops, percentile, visualisation
# Difficulty: Hard  |  Business Case
#
# SCENARIO
# A restaurant tracks covers (number of guests) per table per session.
# 4 weeks × 7 days × 3 sessions (Breakfast/Lunch/Dinner). Seed=80.
# covers = np.random.randint(0, 20, 4*7*3).reshape(4, 7, 3)
# Average spend per session: breakfast=£12, lunch=£22, dinner=£38
# session_avg = np.array([12, 22, 38])
#
# TASKS
# 1. Generate data and compute revenue = covers × session_avg (broadcast).
# 2. Total revenue per week (sum over days and sessions).
# 3. Best day of week across all 4 weeks (mean revenue per day-of-week, argmax).
# 4. Best session overall (mean revenue per session, argmax).
# 5. Flag any day with zero covers in ALL 3 sessions as a "closure day."
# 6. Plot a heatmap (plt.imshow) of mean daily revenue per week
#    (4 weeks × 7 days). Add colorbar and axis labels.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(80)
covers      = np.random.randint(0, 20, 4*7*3).reshape(4, 7, 3)
session_avg = np.array([12, 22, 38])

# ── write your solution below ──────────────────────────────────────────────
