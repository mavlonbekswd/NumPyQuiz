# %% [markdown]
# Quiz 41 — Full Call Centre Analysis
# Theme  : Call Centre
# Topics : reshape, masking, stats, percentile, visualisation
# Difficulty: Hard  |  Business Case
#
# SCENARIO
# A call centre operates 5 days a week, 8 hours a day, with 6 agents.
# You have one full month (20 working days) of hourly call data.
# Generate with seed=42: raw = np.random.randint(2, 25, 20*8*6)
# Reshape to (20, 8, 6) → [day, hour, agent]
#
# TASKS
# 1. Generate and reshape the data.
# 2. Total calls handled per day (sum over hours and agents).
#    Find the top-3 busiest days.
# 3. Average calls per hour-slot across all days and agents.
#    Which hour-slot is consistently busiest?
# 4. For each agent, compute their monthly total and rank them with argsort.
# 5. Flag any hour where the team total exceeded 100 calls as a "peak hour."
#    Print day and hour index for each peak.
# 6. Compute the 25th, 50th, 75th percentile of daily totals.
# 7. Plot a bar chart of daily totals with a horizontal line at the median.
#    Colour bars above median green, below red.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)
raw  = np.random.randint(2, 25, 20 * 8 * 6)
data = raw.reshape(20, 8, 6)

# ── write your solution below ──────────────────────────────────────────────
