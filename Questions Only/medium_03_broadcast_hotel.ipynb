# %% [markdown]
# Quiz 23 — Broadcasting + Reshape
# Theme  : Hotel Room Pricing
# Topics : reshape, broadcasting (2-D × 1-D), np.round
# Difficulty: Medium
#
# SCENARIO
# A hotel has 4 room types across 5 nights (Mon–Fri).
# Base nightly rates (£): [80, 120, 200, 350]   (Standard, Deluxe, Suite, Penthouse)
# Night multipliers      : [1.0, 1.1, 1.2, 1.3, 1.5]  (Mon gets base, Fri is peak)
#
# TASKS
# 1. Create both 1-D arrays.
# 2. Reshape rates to (4,1) so it can broadcast with multipliers (5,) → (4,5) grid.
# 3. Build the full (4, 5) price matrix: price[room, night] = rate * multiplier.
# 4. Round all prices to 2 dp.
# 5. Print the most expensive room+night combination (room index, night index, price).
# 6. Print the total revenue if every room is sold every night.
#
# EXPECTED OUTPUT
# Price matrix (4 rooms × 5 nights):
# [[ 80.   88.   96.  104.  120. ]
#  [120.  132.  144.  156.  180. ]
#  [200.  220.  240.  260.  300. ]
#  [350.  385.  420.  455.  525. ]]
# Most expensive: Room 3, Night 4, £525.0
# Total revenue : £4840.0

# %%
import numpy as np

rates       = np.array([80, 120, 200, 350])
multipliers = np.array([1.0, 1.1, 1.2, 1.3, 1.5])

# ── write your solution below ──────────────────────────────────────────────
