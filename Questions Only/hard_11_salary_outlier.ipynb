# %% [markdown]
# Quiz 51 — Salary Outlier Detection + Clean Analysis
# Theme  : Employee Salaries
# Topics : IQR outlier detection, Z-score, std, percentile, boxplot
# Difficulty: Hard  |  Business Case
#
# SCENARIO
# A company has 80 employees across 3 departments (seed=140):
#   dept       = np.random.choice(["Engineering","Sales","Operations"], 80)
#   salaries   = np.random.normal(45000, 12000, 80)
# Inject 4 outliers: salaries[5]=180000, [20]=2000, [45]=200000, [60]=1500
#
# TASKS
# 1. Generate and inject outliers.
# 2. Detect outliers using BOTH methods:
#    a) Z-score: |z| > 2.5
#    b) IQR: below Q1-1.5*IQR or above Q3+1.5*IQR
#    Print which indices each method flags — compare.
# 3. Remove ALL flagged outliers (union of both methods).
#    Print sample size before and after.
# 4. For each department in the CLEAN dataset: mean, median, min, max, std.
# 5. Find what % of each department earns above the company-wide clean median.
# 6. Plot a Seaborn boxplot of clean salaries per department.
#    Overlay the individual data points (stripplot).

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(140)
dept     = np.random.choice(["Engineering","Sales","Operations"], 80)
salaries = np.random.normal(45000, 12000, 80)
salaries[5]  = 180000
salaries[20] = 2000
salaries[45] = 200000
salaries[60] = 1500

# ── write your solution below ──────────────────────────────────────────────
