# %% [markdown]
# Quiz 15 — Sorting
# Theme  : Stock / Sales Simulation
# Topics : np.sort, np.argsort (basic), ascending/descending
#
# SCENARIO
# Daily closing stock prices (£) for 10 trading days:
# prices = [145.2, 138.7, 152.4, 149.1, 135.0, 160.3, 142.8, 155.9, 148.6, 133.4]
#
# TASKS
# 1. Create the array.
# 2. Sort prices in ascending order.
# 3. Sort prices in descending order.
# 4. Find the index of the highest price using np.argmax.
# 5. Find the index of the lowest price using np.argmin.
#
# EXPECTED OUTPUT
# Ascending  : [133.4 135.  138.7 142.8 145.2 148.6 149.1 152.4 155.9 160.3]
# Descending : [160.3 155.9 152.4 149.1 148.6 145.2 142.8 138.7 135.  133.4]
# Highest day index : 5  (price: 160.3)
# Lowest day index  : 9  (price: 133.4)

# %%
import numpy as np

prices = [145.2, 138.7, 152.4, 149.1, 135.0, 160.3, 142.8, 155.9, 148.6, 133.4]

# ── write your solution below ──────────────────────────────────────────────
