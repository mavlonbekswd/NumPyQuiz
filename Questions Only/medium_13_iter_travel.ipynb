# %% [markdown]
# Quiz 33 — nditer + Structured Iteration
# Theme  : Travel Bookings
# Topics : np.nditer with op_flags, multi-array nditer, ndenumerate
# Difficulty: Medium
#
# SCENARIO
# 3 travel packages × 4 seasons price matrix (£):
# prices = [[499, 599, 749, 399],    # Budget
#            [899, 999,1199, 799],   # Standard
#            [1499,1799,2199,1299]]  # Premium
# Season labels: ["Winter","Spring","Summer","Autumn"]
#
# TASKS
# 1. Create the array.
# 2. Use nditer with op_flags=["readwrite"] to apply a 5% price increase in-place.
# 3. Use np.ndenumerate to print each package/season with its updated price.
# 4. Use a multi-array nditer to iterate over prices and a tax array (10% of price)
#    simultaneously, printing both.
# 5. Find the package-season combo with the highest price after the increase.

# %%
import numpy as np

prices = np.array([[499, 599, 749, 399],
                   [899, 999,1199, 799],
                   [1499,1799,2199,1299]], dtype=float)

packages = ["Budget","Standard","Premium"]
seasons  = ["Winter","Spring","Summer","Autumn"]

# ── write your solution below ──────────────────────────────────────────────
