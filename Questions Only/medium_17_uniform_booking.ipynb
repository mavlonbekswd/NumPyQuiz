# %% [markdown]
# Quiz 37 — Uniform Distribution
# Theme  : Travel Bookings
# Topics : np.random.uniform, histogram, comparison with normal
# Difficulty: Medium
#
# SCENARIO
# A travel platform models waiting time (minutes) before booking confirmation.
# Scenario A: uniform between 1 and 15 minutes (any wait equally likely).
# Scenario B: normally distributed, mean=8, std=2 minutes.
# Simulate 500 bookings for each with seed=23.
#
# TASKS
# 1. Generate both arrays.
# 2. Print mean and std for both — compare.
# 3. Count bookings waiting more than 10 minutes for each scenario.
# 4. Plot overlapping histograms (25 bins each) for visual comparison.
# 5. Mark the mean of each distribution with a vertical line.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(23)

# ── write your solution below ──────────────────────────────────────────────
