# %% [markdown]
# Quiz 40 — searchsorted + Tiered Pricing
# Theme  : E-commerce Product Catalog
# Topics : np.searchsorted, digitize, pricing tier assignment
# Difficulty: Medium
#
# SCENARIO
# An e-commerce site has 5 shipping cost tiers based on order value (£):
# tier_bounds = [0, 25, 50, 100, 200]   → 5 brackets
# tier_labels = ["£4.99","£3.99","£2.99","£0.99","FREE"]
#
# 10 customer order values:
# orders = [18.5, 55.0, 120.0, 9.99, 200.0, 75.0, 45.0, 250.0, 30.0, 15.0]
#
# TASKS
# 1. Create both arrays.
# 2. Use np.searchsorted to find the tier index for each order.
# 3. Map tier indices to tier_labels and print each order with its shipping cost.
# 4. Count how many orders qualify for free shipping (order >= 200).
# 5. Calculate total shipping revenue collected across all orders.
#    (Use numeric costs: [4.99, 3.99, 2.99, 0.99, 0.00])

# %%
import numpy as np

tier_bounds  = np.array([0, 25, 50, 100, 200])
tier_labels  = ["£4.99","£3.99","£2.99","£0.99","FREE"]
tier_costs   = np.array([4.99, 3.99, 2.99, 0.99, 0.00])
orders       = np.array([18.5, 55.0, 120.0, 9.99, 200.0, 75.0, 45.0, 250.0, 30.0, 15.0])

# ── write your solution below ──────────────────────────────────────────────
