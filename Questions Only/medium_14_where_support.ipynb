# %% [markdown]
# Quiz 34 — np.where + Multi-condition Labelling
# Theme  : Customer Support Tickets
# Topics : np.where (nested), np.select, conditional arrays
# Difficulty: Medium
#
# SCENARIO
# 15 support tickets with resolution time (hours) and priority (1=High,2=Med,3=Low):
# times    = [2, 48, 5, 72, 1, 24, 96, 3, 36, 8, 120, 4, 18, 60, 12]
# priority = [1,  2, 1,  3, 1,  2,  3, 1,  2, 1,   3, 2,  2,  3,  1]
#
# SLA rules:
#   Priority 1 (High)  → must resolve in ≤ 4 hours
#   Priority 2 (Med)   → must resolve in ≤ 24 hours
#   Priority 3 (Low)   → must resolve in ≤ 72 hours
#
# TASKS
# 1. Create both arrays.
# 2. Use np.select to label each ticket as "Met SLA" or "Breached SLA".
# 3. Print the count of breached tickets per priority level.
# 4. For breached tickets, calculate how many hours over the SLA they are.
# 5. Print the ticket index, priority, resolution time, and hours over SLA
#    for all breached tickets.

# %%
import numpy as np

times    = np.array([2, 48, 5, 72, 1, 24, 96, 3, 36, 8, 120, 4, 18, 60, 12])
priority = np.array([1,  2, 1,  3, 1,  2,  3, 1,  2, 1,   3, 2,  2,  3,  1])

# ── write your solution below ──────────────────────────────────────────────
