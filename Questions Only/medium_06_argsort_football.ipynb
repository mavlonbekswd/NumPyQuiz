# %% [markdown]
# Quiz 26 — argsort + Fancy Indexing
# Theme  : Football Player Stats
# Topics : np.argsort, multi-key sort (lexsort), fancy indexing for names
# Difficulty: Medium
#
# SCENARIO
# 10 football players, their goals and assists this season:
# players = ["Tomas","Ivan","Luca","Kai","Seb","Jorge","Nico","Ali","Finn","Zak"]
# goals   = [15, 22, 8,  18, 12, 25, 9, 30, 14, 20]
# assists = [7,  10, 12, 8,  15, 6,  11, 5, 9,  13]
#
# TASKS
# 1. Create arrays for goals and assists.
# 2. Sort players by goals (descending) — print ranked names and goals.
# 3. Compute a "contribution" = goals + assists. Sort by contribution descending.
# 4. Print the top-5 contributors (name + contribution score).
# 5. Use np.lexsort to sort by assists descending, then goals descending as tiebreak.
#
# EXPECTED OUTPUT
# Goals ranking   : Ali(30) Jorge(25) Ivan(22) Zak(20) Kai(18) ...
# Top 5 by contrib: Ali(35) Jorge(31) Ivan(32)... (sorted)
# Lexsort ranking : [names in order]

# %%
import numpy as np

players = ["Tomas","Ivan","Luca","Kai","Seb","Jorge","Nico","Ali","Finn","Zak"]
goals   = np.array([15, 22, 8, 18, 12, 25, 9, 30, 14, 20])
assists = np.array([ 7, 10,12,  8, 15,  6,11,  5,  9, 13])

# ── write your solution below ──────────────────────────────────────────────
