# %% [markdown]
# Quiz 58 — University Multi-Year Cohort Comparison
# Theme  : University
# Topics : 3-D arrays, axis masking, trend analysis, visualisation
# Difficulty: Hard  |  Business Case
#
# SCENARIO
# 3 years × 4 subjects × 50 students of exam scores. Seed=210.
# scores = np.random.normal(loc=[[60,65,58,70],[62,68,60,72],[64,70,62,74]],
#                           scale=12, size=(3,4,50))
# (each row of loc = one year, each col = one subject)
# scores.clip(0, 100)
# Subjects: ["Maths","Physics","CS","Stats"]
#
# TASKS
# 1. Generate and clip scores.
# 2. Year-on-year mean improvement per subject (compare year 2 vs 1, year 3 vs 2).
# 3. For each subject, find the % of students achieving distinction (>=70) per year.
# 4. Overall best and worst performing subjects across all years.
# 5. Identify students (by index 0–49) who improved every year in Maths (subject 0):
#    year1_score < year2_score < year3_score.
# 6. Plot mean score per subject per year as a grouped bar chart.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(210)
loc    = np.array([[60,65,58,70],[62,68,60,72],[64,70,62,74]])
scores = np.random.normal(loc[:,:,np.newaxis], 12, (3,4,50)).clip(0, 100)
subjects = ["Maths","Physics","CS","Stats"]

# ── write your solution below ──────────────────────────────────────────────
