# %% [markdown]
# Quiz 32 — Copy vs View (Advanced Operations)
# Theme  : Gym Membership
# Topics : view vs copy with fancy indexing, in-place ops, flags
# Difficulty: Medium
#
# SCENARIO
# Gym member monthly visit counts for 10 members over 6 months:
# Use seed=8: visits = np.random.randint(0, 30, (10, 6))
#
# TASKS
# 1. Generate the array.
# 2. Create a VIEW (slice) of members 2–5 (rows 1:5). Confirm with .base.
# 3. Create a COPY using fancy indexing [1,2,3,4]. Confirm with .base.
# 4. Add a 2-visit bonus to the view — check if the original array changed.
# 5. Add a 5-visit bonus to the copy — check if the original array changed.
# 6. Use the OWNDATA flag to verify ownership for both.
#
# EXPECTED OUTPUT
# view.base is visits   : True
# copy.base is None     : True
# Original after view+2 : changed ← (show first 5 rows)
# Original after copy+5 : NOT changed
# view.flags.owndata    : False
# copy.flags.owndata    : True

# %%
import numpy as np

np.random.seed(8)
visits = np.random.randint(0, 30, (10, 6))

# ── write your solution below ──────────────────────────────────────────────
