# %% [markdown]
# Quiz 50 — Travel Booking Pipeline
# Theme  : Travel Bookings
# Topics : multiple operations, structured simulation, stats pipeline
# Difficulty: Hard  |  Business Case
#
# SCENARIO
# Simulate 300 travel bookings (seed=130):
#   booking_value = np.random.uniform(200, 3000, 300)
#   nights        = np.random.randint(2, 15, 300)
#   destination   = np.random.choice(["Europe","Asia","Americas","Africa"], 300)
#   cancelled     = np.random.choice([0,1], 300, p=[0.88, 0.12])
#
# TASKS
# 1. Generate all arrays.
# 2. Compute revenue per booking = booking_value * (1 - cancelled * 1.0)
#    (cancelled bookings yield £0 in revenue).
# 3. For each destination: count bookings, mean value, cancellation rate.
# 4. Find the 10th percentile of booking_value — bookings below this are "budget."
#    How many budget bookings were cancelled?
# 5. Among non-cancelled bookings, compute value per night = booking_value / nights.
#    Find the top-5 highest value-per-night bookings.
# 6. Plot a boxplot of booking values grouped by destination using Seaborn.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(130)
n           = 300
book_value  = np.random.uniform(200, 3000, n)
nights      = np.random.randint(2, 15, n)
destination = np.random.choice(["Europe","Asia","Americas","Africa"], n)
cancelled   = np.random.choice([0, 1], n, p=[0.88, 0.12])

# ── write your solution below ──────────────────────────────────────────────
