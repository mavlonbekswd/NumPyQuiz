# %% [markdown]
# Quiz 27 — Random: choice, shuffle, permutation
# Theme  : Taxi Ride Simulation
# Topics : np.random.choice, shuffle (in-place), permutation (copy)
# Difficulty: Medium
#
# SCENARIO
# A taxi dispatch system assigns drivers to zones randomly.
# drivers = ["D01","D02","D03","D04","D05","D06","D07","D08"]
# zones   = ["North","South","East","West","Central"]
# fares   = [8.50, 12.00, 6.50, 15.00, 9.00, 11.50, 7.00, 13.00]
#
# TASKS
# 1. Use np.random.seed(99) then np.random.choice to assign a random zone
#    to each driver (8 zones assigned, replace=True allowed).
# 2. Use np.random.permutation to create a shuffled ride order (indices 0-7)
#    without modifying the original drivers array.
# 3. Use np.random.shuffle to shuffle the fares array in-place.
# 4. Simulate 20 fare draws (with replacement) from original fares using choice.
# 5. Print mean and std of those 20 draws.
#
# EXPECTED OUTPUT  (seed=99)
# Zone assignments : [...]
# Ride order (perm): [...]
# Shuffled fares   : [...]
# 20 simulated draws mean: ~X  std: ~Y

# %%
import numpy as np

np.random.seed(99)
drivers = np.array(["D01","D02","D03","D04","D05","D06","D07","D08"])
zones   = np.array(["North","South","East","West","Central"])
fares   = np.array([8.50, 12.00, 6.50, 15.00, 9.00, 11.50, 7.00, 13.00])

# ── write your solution below ──────────────────────────────────────────────
