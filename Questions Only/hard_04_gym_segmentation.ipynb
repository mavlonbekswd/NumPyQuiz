# %% [markdown]
# Quiz 44 — Gym Member Segmentation + Stats
# Theme  : Gym Members
# Topics : fancy indexing, masking, percentile, group stats, argsort
# Difficulty: Hard  |  Business Case
#
# SCENARIO
# 50 gym members. Arrays:
# seed=70 | ages = randint(18, 65, 50)
#          | visits_per_month = randint(1, 30, 50)
#          | membership_type: choice(["Basic","Silver","Gold"], 50)
#          | monthly_spend: uniform(20, 150, 50)
#
# TASKS
# 1. Generate all arrays with seed=70.
# 2. Segment members into activity tiers:
#    Inactive (visits <5), Casual (5-14), Active (15-22), Elite (>22).
# 3. For each tier: print count, mean spend, and mean age.
# 4. Find the top-10 members by spend (argsort). What are their membership types?
# 5. Among Gold members only: find the median visits and flag those below median
#    as "At-risk Gold" (potential downgrade). Print count.
# 6. Compute the 80th percentile of spend. Find all members above it —
#    what % are Gold?

# %%
import numpy as np

np.random.seed(70)
n   = 50
ages             = np.random.randint(18, 65, n)
visits           = np.random.randint(1, 30, n)
membership_type  = np.random.choice(["Basic","Silver","Gold"], n)
monthly_spend    = np.random.uniform(20, 150, n)

# ── write your solution below ──────────────────────────────────────────────
