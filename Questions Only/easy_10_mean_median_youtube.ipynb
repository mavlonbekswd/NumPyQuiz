# %% [markdown]
# Quiz 10 — Mean & Median
# Theme  : YouTube Analytics
# Topics : np.mean, np.median, effect of outliers
#
# SCENARIO
# A YouTube channel's daily view counts for 10 days:
# views = [1200, 980, 1050, 1300, 15000, 1100, 900, 1250, 1080, 970]
# (Day 5 went viral with 15,000 views.)
#
# TASKS
# 1. Create the array.
# 2. Calculate mean and median views.
# 3. Remove the viral day (index 4) and recalculate both.
# 4. Print both sets of results and observe the difference.
# 5. Print which measure (mean/median) is more representative of a typical day.
#
# EXPECTED OUTPUT
# With viral day  — Mean: 2483.0  |  Median: 1065.0
# Without viral   — Mean: 1092.2  |  Median: 1050.0
# Median is more representative of a typical day.

# %%
import numpy as np

views_with = [1200, 980, 1050, 1300, 15000, 1100, 900, 1250, 1080, 970]
views_without = [1200, 980, 1050, 1300, 1100, 900, 1250, 1080, 970]

# ── write your solution below ──────────────────────────────────────────────

arr_views_with = np.array(views_with)

mean_with = np.mean(arr_views_with)
med_with = np.median(arr_views_with)

print("Mean with viral day", mean_with)
print("Medm with viral day", med_with)

#---------------------------------------------------------------------------------

arr_views_without = np.array(views_without)

mean_without = round(np.mean(arr_views_without),2)
med_without = np.median(arr_views_without)


print("Mean without viral day", mean_without)
print("Medm without viral day", med_without)
# Out:
# Mean with viral day 2483.0
# Medm with viral day 1090.0
# Mean without viral day 1092.22
# Medm without viral day 1080.0
