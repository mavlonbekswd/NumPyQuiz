# %% [markdown]
# Quiz 43 — University Grade Distribution
# Theme  : University
# Topics : normal dist, percentile, std, visualisation, cohort comparison
# Difficulty: Hard  |  Business Case
#
# SCENARIO
# Two cohorts sat the same exam:
# Cohort A (100 students): mean=62, std=10, seed=60
# Cohort B (100 students): mean=68, std=15, seed=61  (more varied cohort)
# Clip all grades to [0, 100].
#
# TASKS
# 1. Generate both cohorts. Clip to [0,100].
# 2. Print mean, median, std, Q1, Q3 for each cohort.
# 3. Count students in each grade band per cohort:
#    Fail <40 | Pass 40-59 | Merit 60-79 | Distinction >=80
# 4. Cohort A students above Cohort B's 75th percentile — how many?
# 5. Plot overlapping histograms of both cohorts.
#    Add vertical lines for each cohort's mean. Add a legend.
# 6. Determine which cohort performed better overall and explain why
#    (consider both mean and spread).

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(60)
cohort_a = np.clip(np.random.normal(62, 10, 100), 0, 100)
np.random.seed(61)
cohort_b = np.clip(np.random.normal(68, 15, 100), 0, 100)

# ── write your solution below ──────────────────────────────────────────────
