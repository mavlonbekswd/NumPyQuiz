# %% [markdown]
# Quiz 39 — Poisson Distribution
# Theme  : Restaurant Arrivals
# Topics : np.random.poisson, expected value, visualisation
# Difficulty: Medium
#
# SCENARIO
# A restaurant receives an average of 8 customer groups per hour (lambda=8).
# Simulate arrivals for 100 one-hour windows (seed=37).
#
# TASKS
# 1. Generate 100 hourly arrival counts with np.random.poisson(lam=8, size=100).
# 2. Print simulated mean and std. Compare with theoretical (mean=lam, std=sqrt(lam)).
# 3. Find what % of hours had more than 12 arrivals (restaurant gets overwhelmed).
# 4. Find what % of hours had fewer than 5 arrivals (kitchen underutilised).
# 5. Plot a bar chart of the frequency of each arrival count.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(37)

# ── write your solution below ──────────────────────────────────────────────
