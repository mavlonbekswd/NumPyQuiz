# %% [markdown]
# Quiz 36 — Variance + Volatility Analysis
# Theme  : Stock / Sales Simulation
# Topics : np.var, np.std, rolling comparison, visualisation
# Difficulty: Medium
#
# SCENARIO
# Two stocks' daily closing prices over 30 trading days (seed=17):
# stock_a = np.random.normal(150, 5, 30)    # stable blue-chip
# stock_b = np.random.normal(150, 20, 30)   # volatile growth stock
#
# TASKS
# 1. Generate both arrays with seed=17.
# 2. Print mean, variance, and std for each stock.
# 3. Compute daily percentage change for each: pct = (price[i] - price[i-1]) / price[i-1] * 100
#    Use array slicing (not a loop).
# 4. Print which stock has higher volatility (based on std of daily % change).
# 5. Plot both stock prices on the same chart with a legend.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(17)

# ── write your solution below ──────────────────────────────────────────────
